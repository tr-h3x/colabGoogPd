# %% [markdown]
# <a href="https://colab.research.google.com/github/tr-h3x/colabGoogPd/blob/main/filterData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('rand.csv')

# %%
df.head()
# Out:
#      ID First Name Last Name  Gender   Age  Salary         DOB Education  \
# 0  1000       Owen     Craig    Male  18.0    5434    02/05/81    Master
# 1  1001    Valeria  Richards  Female  29.0    3768  29/08/1976  Doctoral
# 2  1002   Kimberly   Douglas  Female  22.0     869    02/06/81    Master
# 3  1003     Audrey  Campbell  Female  30.0    6928  29/08/1977    Master
# 4  1004     Jordan     Kelly    Male  18.0     623    02/07/81  Bachelor
#
#      Occupation
# 0         Medic
# 1      Composer
# 2      Salesman
# 3  Veterinarian
# 4       Insurer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          100 non-null    int64
#  1   First Name  100 non-null    object
#  2   Last Name   100 non-null    object
#  3   Gender      100 non-null    object
#  4   Age         97 non-null     float64
#  5   Salary      100 non-null    int64
#  6   DOB         100 non-null    object
#  7   Education   100 non-null    object
#  8   Occupation  100 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 7.2+ KB

# %%
df['ID'].is_unique
# Out:
# True

# %%
df = df.set_index('ID')

# %%
df.head()
# Out:
#      First Name Last Name  Gender   Age  Salary         DOB Education  \
# ID
# 1000       Owen     Craig    Male  18.0    5434    02/05/81    Master
# 1001    Valeria  Richards  Female  29.0    3768  29/08/1976  Doctoral
# 1002   Kimberly   Douglas  Female  22.0     869    02/06/81    Master
# 1003     Audrey  Campbell  Female  30.0    6928  29/08/1977    Master
# 1004     Jordan     Kelly    Male  18.0     623    02/07/81  Bachelor
#
#         Occupation
# ID
# 1000         Medic
# 1001      Composer
# 1002      Salesman
# 1003  Veterinarian
# 1004       Insurer

# %%
df.isnull().sum()
# Out:
# First Name    0
# Last Name     0
# Gender        0
# Age           3
# Salary        0
# DOB           0
# Education     0
# Occupation    0
# dtype: int64

# %%
df[df['Age'].isna()]
# Out:
#      First Name   Last Name  Gender  Age  Salary       DOB        Education  \
# ID
# 1010     Andrew       Clark    Male  NaN    3488  02/08/81           Master
# 1030     Amanda  Cunningham  Female  NaN    6602  02/10/81         Bachelor
# 1060     Sawyer       Brown    Male  NaN    6721  02/15/81  Lower secondary
#
#         Occupation
# ID
# 1010    Programmer
# 1030          Chef
# 1060  Veterinarian

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 1000 to 1099
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  97 non-null     object
#  1   Last Name   97 non-null     object
#  2   Gender      97 non-null     object
#  3   Age         97 non-null     float64
#  4   Salary      97 non-null     int64
#  5   DOB         97 non-null     object
#  6   Education   97 non-null     object
#  7   Occupation  97 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.8+ KB

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1000 to 1099
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  100 non-null    object
#  1   Last Name   100 non-null    object
#  2   Gender      100 non-null    object
#  3   Age         100 non-null    float64
#  4   Salary      100 non-null    int64
#  5   DOB         100 non-null    object
#  6   Education   100 non-null    object
#  7   Occupation  100 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 7.0+ KB

# %%
df['Age'].mean()
# Out:
# 23.494845360824737

# %%
df['Age'] = df['Age'].astype('int')

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['DOB'] = pd.to_datetime(df['DOB'])
df.head()
# Out:
#      First Name Last Name  Gender  Age  Salary        DOB Education  \
# ID
# 1000       Owen     Craig    Male   18    5434 1981-02-05    Master
# 1001    Valeria  Richards  Female   29    3768 1976-08-29  Doctoral
# 1002   Kimberly   Douglas  Female   22     869 1981-02-06    Master
# 1003     Audrey  Campbell  Female   30    6928 1977-08-29    Master
# 1004     Jordan     Kelly    Male   18     623 1981-02-07  Bachelor
#
#         Occupation
# ID
# 1000         Medic
# 1001      Composer
# 1002      Salesman
# 1003  Veterinarian
# 1004       Insurer

# %%
df['Gender'].value_counts()
# Out:
# Male      50
# Female    50
# Name: Gender, dtype: int64

# %%
df['Gender'] = df['Gender'].replace('Mile', 'Male')

# %%
df['Gender'] = df['Gender'].astype('category')
df['Gender'].dtype
# Out:
# CategoricalDtype(categories=['Female', 'Male'], ordered=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1000 to 1099
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  100 non-null    object
#  1   Last Name   100 non-null    object
#  2   Gender      100 non-null    category
#  3   Age         100 non-null    int64
#  4   Salary      100 non-null    int64
#  5   DOB         100 non-null    datetime64[ns]
#  6   Education   100 non-null    object
#  7   Occupation  100 non-null    object
# dtypes: category(1), datetime64[ns](1), int64(2), object(4)
# memory usage: 6.5+ KB

# %%
df = df.drop(columns=['Education', 'Occupation'])
df.columns
# Out:
# Index(['First Name', 'Last Name', 'Gender', 'Age', 'Salary', 'DOB'], dtype='object')

# %%
df.head(2)
# Out:
#      First Name Last Name  Gender  Age  Salary        DOB
# ID
# 1000       Owen     Craig    Male   18    5434 1981-02-05
# 1001    Valeria  Richards  Female   29    3768 1976-08-29

# %%
df.loc[1005:1010]
# Out:
#      First Name   Last Name  Gender  Age  Salary        DOB
# ID
# 1005     Fenton     Perkins    Male   20    9036 1978-08-29
# 1006     Audrey  Cunningham  Female   24    8880 1981-02-06
# 1007     Jordan        Hill    Male   24    7840 1977-08-29
# 1008     Miller      Rogers    Male   18    3844 1981-02-07
# 1009     Alissa   Armstrong  Female   27    2626 1978-08-29
# 1010     Andrew       Clark    Male   23    3488 1981-02-08

# %%
df.iloc[5:10]
# Out:
#      First Name   Last Name  Gender  Age  Salary        DOB
# ID
# 1005     Fenton     Perkins    Male   20    9036 1978-08-29
# 1006     Audrey  Cunningham  Female   24    8880 1981-02-06
# 1007     Jordan        Hill    Male   24    7840 1977-08-29
# 1008     Miller      Rogers    Male   18    3844 1981-02-07
# 1009     Alissa   Armstrong  Female   27    2626 1978-08-29

# %%
df.at[1007, 'Salary']
# Out:
# 7840

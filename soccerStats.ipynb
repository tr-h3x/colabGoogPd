# %% [markdown]
# <a href="https://colab.research.google.com/github/tr-h3x/colabGoogPd/blob/main/soccerStats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('MessiRonaldo.csv')

# %%
#df.head(2)

# %%
#df.tail(2)

# %%
#df.info()
#df.shape
#df.dtypes
#df.describe()
df.head(2)
# Out:
#     Season   Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  CL_Goals  \
# 0  2017-18    Messi          34         12        36       2996         6
# 1  2017-18  Ronaldo          26          5        27       2297        15
#
#    CL_Asts  CL_Aps  CL_Mins
# 0        2      10      783
# 1        3      13     1170

# %%
goals = df[['Player','Liga_Goals','CL_Goals']]
goals.head()
# Out:
#     Player  Liga_Goals  CL_Goals
# 0    Messi          34         6
# 1  Ronaldo          26        15
# 2    Messi          37        11
# 3  Ronaldo          25        12
# 4    Messi          26         6

# %%
messi = df[df['Player'] == 'Messi']
ronaldo = df[df['Player'] == 'Ronaldo']
messi.head()
# Out:
#     Season Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  CL_Goals  \
# 0  2017-18  Messi          34         12        36       2996         6
# 2  2016-17  Messi          37          9        34       2832        11
# 4  2015-16  Messi          26         16        33       2729         6
# 6  2014-15  Messi          43         21        38       3375        10
# 8  2013-14  Messi          28         12        31       2498         8
#
#    CL_Asts  CL_Aps  CL_Mins
# 0        2      10      783
# 2        2       9      810
# 4        1       7      630
# 6        6      13     1145
# 8        1       7      630

# %%
messi['Liga_Goals'].sum()
# Out:
# 329

# %%
ronaldo['Liga_Goals'].sum()
# Out:
# 311

# %%
messi['Liga_Goals'].sum() + messi['CL_Goals'].sum()
# Out:
# 412

# %%
ronaldo['Liga_Goals'].sum() + ronaldo['CL_Goals'].sum()
# Out:
# 416

# %%
df[df['Liga_Goals'] >= 40]
# Out:
#      Season   Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  CL_Goals  \
# 6   2014-15    Messi          43         21        38       3375        10
# 7   2014-15  Ronaldo          48         16        35       3096        10
# 10  2012-13    Messi          46         14        32       2629         8
# 12  2011-12    Messi          50         20        37       3270        14
# 13  2011-12  Ronaldo          46         13        38       3353        10
# 15  2010-11  Ronaldo          40         13        34       2914         6
#
#     CL_Asts  CL_Aps  CL_Mins
# 6         6      13     1145
# 7         4      12     1064
# 10        3      11      827
# 12        9      11      990
# 13        4      10      930
# 15        4      12     1018
